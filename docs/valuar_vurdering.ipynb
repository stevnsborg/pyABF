# %% [markdown]
# # Udregning af Valuarvurdering
#
# Dette er et overslag/estimat basseret på nogle konkrete antagelser

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
AREAL_RENOVERING = 6572
NYEAR = 15


AREAL_RENOVERING/NYEAR
# Out:
# 438.1333333333333

# %%
def generate_interest_rate(nyear:int, rate:float):
    return np.asarray([(1+rate)**i for i in range(1, nyear + 1)])

# %%
generate_interest_rate(15, 0.02)
# Out:
# array([1.02      , 1.0404    , 1.061208  , 1.08243216, 1.1040808 ,
#        1.12616242, 1.14868567, 1.17165938, 1.19509257, 1.21899442,
#        1.24337431, 1.26824179, 1.29360663, 1.31947876, 1.34586834])
